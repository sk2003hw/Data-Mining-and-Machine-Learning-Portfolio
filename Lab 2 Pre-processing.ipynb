# %%
import sys
assert sys.version_info >= (3, 5)
# Python ≥3.5 is required

# Scikit-Learn ≥0.20 is required
import sklearn
assert sklearn.__version__ >= "0.20"

# Common imports
import numpy as np
import os
import tarfile
import urllib
import pandas as pd
import urllib.request

# To plot pretty figures
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

# Reference- https://github.com/ageron/handson-ml2/blob/master/02_end_to_end_machine_learning_project.ipynb

# Where to save the figures; method can be used later
PROJECT_ROOT_DIR = "."
CHAPTER_ID = "end_to_end_project"
IMAGES_PATH = os.path.join(PROJECT_ROOT_DIR, "images", CHAPTER_ID)
os.makedirs(IMAGES_PATH, exist_ok=True)

def save_fig(fig_id, tight_layout=True, fig_extension="png", resolution=300):
    path = os.path.join(IMAGES_PATH, fig_id + "." + fig_extension)
    print("Saving figure", fig_id)
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format=fig_extension, dpi=resolution)

# %%
data = pd.read_csv("student-por.csv") # reading the csv file with the data

print(data.shape) # to understand the dimensions of the dataset
print("rows = {}".format(data.shape[0])) # to display the number of rows/instances
print("columns = {}".format(data.shape[1])) # to display the number of columns/attributes
# Out:
# (649, 33)
# rows = 649
# columns = 33

# %%
data.head(10) # to get a glimpse of the data
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1     GP   F   17       U     GT3       T     1     1   at_home     other
# 2     GP   F   15       U     LE3       T     1     1   at_home     other
# 3     GP   F   15       U     GT3       T     4     2    health  services
# 4     GP   F   16       U     GT3       T     3     3     other     other
# 5     GP   M   16       U     LE3       T     4     3  services     other
# 6     GP   M   16       U     LE3       T     2     2     other     other
# 7     GP   F   17       U     GT3       A     4     4     other   teacher
# 8     GP   M   15       U     LE3       A     3     2  services     other
# 9     GP   M   15       U     GT3       T     3     4     other     other
#
#    ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0  ...      4        3      4     1     1      3        4   0  11  11
# ...

# %%
data.info() # to understand the attributes and their types
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      649 non-null    object
#  1   sex         649 non-null    object
#  2   age         649 non-null    int64
#  3   address     649 non-null    object
#  4   famsize     649 non-null    object
#  5   Pstatus     649 non-null    object
#  6   Medu        649 non-null    int64
#  7   Fedu        649 non-null    int64
#  8   Mjob        649 non-null    object
#  9   Fjob        649 non-null    object
#  10  reason      649 non-null    object
#  11  guardian    649 non-null    object
#  12  traveltime  649 non-null    int64
#  13  studytime   649 non-null    int64
#  14  failures    649 non-null    int64
#  15  schoolsup   649 non-null    object
#  16  famsup      649 non-null    object
#  17  paid        649 non-null    object
#  18  activities  649 non-null    object
# ...

# %%
data.isnull().sum().sum() # to check for any null values in the dataset
# Out:
# 0

# %%
data.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  649.000000  649.000000  649.000000  649.000000  649.000000  649.000000
# mean    16.744222    2.514638    2.306626    1.568567    1.930663    0.221880
# std      1.218138    1.134552    1.099931    0.748660    0.829510    0.593235
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    1.000000    1.000000    1.000000    0.000000
# 50%     17.000000    2.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  649.000000  649.000000  649.000000  649.000000  649.000000  649.000000
# mean     3.930663    3.180277    3.184900    1.502311    2.280431    3.536210
# ...

# %%
data.rename(columns = {'famsize':'fam_size','Pstatus':'parent_status', 'Medu':'mom_edu', 'Fedu':'dad_edu', 'Mjob':'mom_job', 'Fjob':'dad_job', 'schoolsup':'school_support', 'famsup':'fam_support', 'paid':'paid_class', 'higher':'higher_edu', 'romantic':'romantic_relations', 'famrel':'fam_relations', 'goout':'outings', 'Dalc':'workday_alcohol', 'Walc':'weekend_alcohol'}, inplace = True)

# %%
data.info() # to understand the attributes and their types
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 33 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   school              649 non-null    object
#  1   sex                 649 non-null    object
#  2   age                 649 non-null    int64
#  3   address             649 non-null    object
#  4   fam_size            649 non-null    object
#  5   parent_status       649 non-null    object
#  6   mom_edu             649 non-null    int64
#  7   dad_edu             649 non-null    int64
#  8   mom_job             649 non-null    object
#  9   dad_job             649 non-null    object
#  10  reason              649 non-null    object
#  11  guardian            649 non-null    object
#  12  traveltime          649 non-null    int64
#  13  studytime           649 non-null    int64
#  14  failures            649 non-null    int64
# ...

# %%
copy_data = data.select_dtypes(include=['object','int64']).copy()

# %%
data.head()
# Out:
#   school sex  age address fam_size parent_status  mom_edu  dad_edu  mom_job  \
# 0     GP   F   18       U      GT3             A        4        4  at_home
# 1     GP   F   17       U      GT3             T        1        1  at_home
# 2     GP   F   15       U      LE3             T        1        1  at_home
# 3     GP   F   15       U      GT3             T        4        2   health
# 4     GP   F   16       U      GT3             T        3        3    other
#
#     dad_job  ... fam_relations freetime  outings  workday_alcohol  \
# 0   teacher  ...             4        3        4                1
# 1     other  ...             5        3        3                1
# 2     other  ...             4        3        2                2
# 3  services  ...             3        2        2                1
# 4     other  ...             4        3        2                1
#
#    weekend_alcohol health absences  G1  G2  G3
# 0                1      3        4   0  11  11
# ...

# %%
print(copy_data['reason'].value_counts()) # value_counts on a data frame column returns the count of unique values in that column
# Out:
# course        285
# home          149
# reputation    143
# other          72
# Name: reason, dtype: int64

# %%
print(copy_data['reason'].value_counts().count())
# Out:
# 4

# %%
print(copy_data['paid_class'].value_counts())
# Out:
# no     610
# yes     39
# Name: paid_class, dtype: int64

# %%
copy_data['fam_relations'].value_counts()
# Out:
# 4    317
# 5    180
# 3    101
# 2     29
# 1     22
# Name: fam_relations, dtype: int64

# %%
data.sample()
# Out:
#    school sex  age address fam_size parent_status  mom_edu  dad_edu mom_job  \
# 66     GP   M   15       U      GT3             A        4        4   other
#
#      dad_job  ... fam_relations freetime  outings  workday_alcohol  \
# 66  services  ...             1        3        3                5
#
#     weekend_alcohol health absences  G1  G2  G3
# 66                5      3        0  11  12  12
#
# [1 rows x 33 columns]

# %%
data.duplicated().describe() # one unique value of false means no duplicate value
# Out:
# count       649
# unique        1
# top       False
# freq        649
# dtype: object

# %%
# data.drop_duplicates() # we do not have duplicate values in our dataset as proved above
# data.dropna() # Drops rows with null or missing values # we do not have null values

data.dropna() # dropping duplicate values, if present in dataset
# Out:
#     school sex  age address fam_size parent_status  mom_edu  dad_edu  \
# 0       GP   F   18       U      GT3             A        4        4
# 1       GP   F   17       U      GT3             T        1        1
# 2       GP   F   15       U      LE3             T        1        1
# 3       GP   F   15       U      GT3             T        4        2
# 4       GP   F   16       U      GT3             T        3        3
# ..     ...  ..  ...     ...      ...           ...      ...      ...
# 644     MS   F   19       R      GT3             T        2        3
# 645     MS   F   18       U      LE3             T        3        1
# 646     MS   F   18       U      GT3             T        1        1
# 647     MS   M   17       U      LE3             T        3        1
# 648     MS   M   18       R      LE3             T        3        2
#
#       mom_job   dad_job  ... fam_relations freetime  outings  workday_alcohol  \
# ...
